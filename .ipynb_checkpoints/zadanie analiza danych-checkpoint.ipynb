# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
HR_data = pd.read_csv('HRDataset.csv')
HR_data
# Out:
#             Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  \
# 0            1.0     1.0          3.0                     1.0    28.50  ...
# 1            1.0     1.0          3.0                     0.0    23.00  ...
# 2            1.0     1.0          3.0                     0.0    29.00  ...
# 3            1.0     1.0          3.0                     0.0    21.50  ...
# 4            1.0     1.0          3.0                     0.0    16.56  ...
# ..           ...     ...          ...                     ...      ...  ...
# 396          NaN     NaN          NaN                     NaN      NaN  ...
# 397          NaN     NaN          NaN                     NaN      NaN  ...
# 398          NaN     NaN          NaN                     NaN      NaN  ...
# 399          NaN     NaN          NaN                     NaN      NaN  ...
# 400          NaN     NaN          NaN                     NaN      NaN  ...
#
#         Department         ManagerName ManagerID       RecruitmentSource  \
# 0    Admin Offices  Brandon R. LeBlanc       1.0      Diversity Job Fair
# 1    Admin Offices  Brandon R. LeBlanc       1.0      Website Banner Ads
# 2    Admin Offices  Brandon R. LeBlanc       1.0         Internet Search
# 3    Admin Offices  Brandon R. LeBlanc       1.0  Pay Per Click - Google
# 4    Admin Offices  Brandon R. LeBlanc       1.0      Website Banner Ads
# ..             ...                 ...       ...                     ...
# 396            NaN                 NaN       NaN                     NaN
# 397            NaN                 NaN       NaN                     NaN
# 398            NaN                 NaN       NaN                     NaN
# 399            NaN                 NaN       NaN                     NaN
# 400            NaN                 NaN       NaN                     NaN
#
#      PerformanceScore EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0         Fully Meets             2.04             2.0                  6.0
# 1         Fully Meets             5.00             4.0                  4.0
# 2         Fully Meets             3.90             5.0                  5.0
# 3         Fully Meets             3.24             3.0                  4.0
# 4         Fully Meets             5.00             3.0                  5.0
# ..                ...              ...             ...                  ...
# 396               NaN              NaN             NaN                  NaN
# 397               NaN              NaN             NaN                  NaN
# 398               NaN              NaN             NaN                  NaN
# 399               NaN              NaN             NaN                  NaN
# 400               NaN              NaN             NaN                  NaN
#
#     LastPerformanceReview_Date DaysLateLast30
# 0                    1/15/2019            0.0
# 1                    1/17/2019            0.0
# 2                    1/18/2019            0.0
# 3                          NaN            NaN
# 4                    1/15/2019            0.0
# ..                         ...            ...
# 396                        NaN            NaN
# 397                        NaN            NaN
# 398                        NaN            NaN
# 399                        NaN            NaN
# 400                        NaN            NaN
#
# [401 rows x 35 columns]

# %% [markdown]
# Step 0: Preparation of database, remove empty rows. Change date formats.

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(HR_data.isnull())
# Out:
# <AxesSubplot:>

# %%
HR_data = HR_data.dropna(thresh=1)
HR_data
# Out:
#               Employee_Name         EmpID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 305          Daniele, Ann    1.411071e+09        1.0              1.0
# 306          Lajiri,  Jyoti  1.108028e+09        1.0              1.0
# 307  Semizoglou, Jeremiah    9.040136e+08        1.0              1.0
# 308              South, Joe  1.308061e+09        0.0              0.0
# 309         Warfield, Sarah  1.301052e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# 0         0.0          1.0     1.0          3.0                     1.0
# 1         1.0          1.0     1.0          3.0                     0.0
# 2         1.0          1.0     1.0          3.0                     0.0
# 3         0.0          1.0     1.0          3.0                     0.0
# 4         0.0          1.0     1.0          3.0                     0.0
# ..        ...          ...     ...          ...                     ...
# 305       0.0          3.0     3.0          3.0                     0.0
# 306       1.0          3.0     3.0          3.0                     0.0
# 307       1.0          2.0     3.0          3.0                     0.0
# 308       1.0          1.0     3.0          3.0                     0.0
# 309       0.0          1.0     3.0          3.0                     0.0
#
#      PayRate  ...     Department         ManagerName ManagerID  \
# 0      28.50  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 1      23.00  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 2      29.00  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 3      21.50  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 4      16.56  ...  Admin Offices  Brandon R. LeBlanc       1.0
# ..       ...  ...            ...                 ...       ...
# 305    54.10  ...          IT/IS        Peter Monroe       7.0
# 306    56.20  ...          IT/IS        Peter Monroe       7.0
# 307    53.80  ...          IT/IS        Peter Monroe       7.0
# 308    53.00  ...          IT/IS        Peter Monroe       7.0
# 309    55.20  ...          IT/IS        Peter Monroe       7.0
#
#           RecruitmentSource  PerformanceScore EngagementSurvey  \
# 0        Diversity Job Fair       Fully Meets             2.04
# 1        Website Banner Ads       Fully Meets             5.00
# 2           Internet Search       Fully Meets             3.90
# 3    Pay Per Click - Google       Fully Meets             3.24
# 4        Website Banner Ads       Fully Meets             5.00
# ..                      ...               ...              ...
# 305         Vendor Referral       Fully Meets             1.55
# 306       Employee Referral       Fully Meets             4.46
# 307    On-campus Recruiting       Fully Meets             3.27
# 308       Employee Referral       Fully Meets             5.00
# 309       Employee Referral       Fully Meets             1.06
#
#     EmpSatisfaction SpecialProjectsCount LastPerformanceReview_Date  \
# 0               2.0                  6.0                  1/15/2019
# 1               4.0                  4.0                  1/17/2019
# 2               5.0                  5.0                  1/18/2019
# 3               3.0                  4.0                        NaN
# 4               3.0                  5.0                  1/15/2019
# ..              ...                  ...                        ...
# 305             5.0                  8.0                  2/12/2019
# 306             5.0                  6.0                   1/7/2019
# 307             4.0                  5.0                  1/14/2019
# 308             3.0                  4.0                   1/2/2019
# 309             4.0                  8.0                   2/5/2019
#
#     DaysLateLast30
# 0              0.0
# 1              0.0
# 2              0.0
# 3              NaN
# 4              0.0
# ..             ...
# 305            0.0
# 306            0.0
# 307            0.0
# 308            0.0
# 309            0.0
#
# [310 rows x 35 columns]

# %%
HR_data['DOB'] = pd.to_datetime(HR_data['DOB'],format='%m/%d/%y')

# %%
HR_data['DateofTermination'] = pd.to_datetime(HR_data['DateofTermination'],format='%m/%d/%y')

# %%
HR_data['DateofHire'] = pd.to_datetime(HR_data['DateofHire'],format='%m/%d/%y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0f2e14d87cce> in <module>
# ----> 1 HR_data['DateofHire'] = pd.to_datetime(HR_data['DateofHire'],format='%m/%d/%y')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391
#     392     if format is not None:
# --> 393         res = _to_datetime_with_format(
#     394             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     395         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     511             return DatetimeIndex._simple_new(dta, name=name)
#     512         except (ValueError, TypeError):
# --> 513             raise err
#     514
#     515
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498
#     499         # fallback
# --> 500         res = _array_strptime_with_fallback(
#     501             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     502         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434
#     435     try:
# --> 436         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     437         if "%Z" in fmt or "%z" in fmt:
#     438             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: unconverted data remains: 08

# %% [markdown]
# Step 1: check if there is any correlation between MangerID and employee PerformanceScore.

# %%
sns.distplot(HR_data['PerfScoreID'])
# Out:
# /home/agnieszka/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PerfScoreID', ylabel='Density'>

# %%
figure = plt.figure(figsize = (15, 5))
axes = figure.add_axes([0,0,1,1])
sns.barplot(x='ManagerID', y='PerfScoreID', data = HR_data)
# Out:
# <Axes:xlabel='ManagerID', ylabel='PerfScoreID'>

# %%
figure = plt.figure(figsize = (15, 5))
axes = figure.add_axes([0,0,1,1])
sns.boxplot(x='ManagerID', y='PerfScoreID', data = HR_data)
# Out:
# <Axes:xlabel='ManagerID', ylabel='PerfScoreID'>

# %%
sns.lmplot(x='ManagerID', y='PerfScoreID', data = HR_data)

# %% [markdown]
# Conclusion: managers rate employees performance in 4-step scale (0-3). For all managers the mean value is around 3. It is also the most common performance rating. There is no clear correlation between ManagerID and employee PerformanceScore.

# %% [markdown]
# Step2: check what RecruitmentSource is the best if the employment length is our priority.

# %%
import datetime
today = datetime.date.today().strftime("%m/%d/%y")
today
# Out:
# '01/21/22'

# %%
HR_data['DateofTermination'].fillna(today)
# Out:
# 0     2022-01-21
# 1     2022-01-21
# 2     2022-01-21
# 3     2015-04-15
# 4     2022-01-21
#          ...
# 305   2022-01-21
# 306   2022-01-21
# 307   2022-01-21
# 308   2022-01-21
# 309   2022-01-21
# Name: DateofTermination, Length: 310, dtype: datetime64[ns]

# %%
HR_data['DateofTermination'] = pd.to_datetime(HR_data['DateofTermination'], format = '%m/%d/%y')

# %%
HR_data['DateofTermination']
# Out:
# 0            NaT
# 1            NaT
# 2            NaT
# 3     2015-04-15
# 4            NaT
#          ...
# 305          NaT
# 306          NaT
# 307          NaT
# 308          NaT
# 309          NaT
# Name: DateofTermination, Length: 310, dtype: datetime64[ns]

# %%
def work_period_calculation(row):
    return (row['DateofTermination'] - row['DateofHire'])

# %%
#HR_data['Work_Period'] = HR_data.apply(lambda row: work_period_calculation(row), axis = 1)
#HR_data['Work_Period'] = HR_data['Work_Period'].dt.days.astype('int16')

# %%
#sns.barplot(x='RecruitmentSource', y='Work_Period', data = HR_data_raw)

# %% [markdown]
# Step 3: marital description influence on the employee's work satisfaction.

# %%
sns.lmplot(x='MaritalStatusID', y='EmpSatisfaction', data = HR_data)

# %%
sns.barplot(x='MaritalStatusID', y='EmpSatisfaction', data = HR_data, estimator = np.median)
# Out:
# <AxesSubplot:xlabel='MaritalStatusID', ylabel='EmpSatisfaction'>

# %%
sns.violinplot(x='MaritalStatusID', y='EmpSatisfaction', data = HR_data)
# Out:
# <AxesSubplot:xlabel='MaritalStatusID', ylabel='EmpSatisfaction'>

# %%
marital_desc = {marital_ID: marital_desc for marital_ID, marital_desc in zip(HR_data['MaritalStatusID'].unique(), HR_data['MaritalDesc'].unique())}
sorted(marital_desc.items())
# Out:
# [(0.0, 'Single'),
#  (1.0, 'Married'),
#  (2.0, 'Divorced'),
#  (3.0, 'Separated'),
#  (4.0, 'Widowed')]

# %% [markdown]
# Conclusion: There seems to be no clear correlation between employee's marital status and satisfaction from work. For all employees groups the median EmpSatisfaction factor equal 4.S However it can be observed that in group 3 - 'Separated employees' the spread of values is the largest.

# %% [markdown]
# Step 4: age structure of employees

# %%
HR_data['DOB']
# Out:
# 0     1987-11-24
# 1     1984-04-26
# 2     1986-09-01
# 3     1985-09-16
# 4     1988-05-19
#          ...
# 305   2052-01-18
# 306   1986-04-23
# 307   1983-02-09
# 308   2065-09-09
# 309   1978-05-02
# Name: DOB, Length: 310, dtype: datetime64[ns]

# %%
HR_data['yearOfBirth'] = HR_data['DOB'].dt.year

# %%
HR_data
# Out:
#               Employee_Name         EmpID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 305          Daniele, Ann    1.411071e+09        1.0              1.0
# 306          Lajiri,  Jyoti  1.108028e+09        1.0              1.0
# 307  Semizoglou, Jeremiah    9.040136e+08        1.0              1.0
# 308              South, Joe  1.308061e+09        0.0              0.0
# 309         Warfield, Sarah  1.301052e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# 0         0.0          1.0     1.0          3.0                     1.0
# 1         1.0          1.0     1.0          3.0                     0.0
# 2         1.0          1.0     1.0          3.0                     0.0
# 3         0.0          1.0     1.0          3.0                     0.0
# 4         0.0          1.0     1.0          3.0                     0.0
# ..        ...          ...     ...          ...                     ...
# 305       0.0          3.0     3.0          3.0                     0.0
# 306       1.0          3.0     3.0          3.0                     0.0
# 307       1.0          2.0     3.0          3.0                     0.0
# 308       1.0          1.0     3.0          3.0                     0.0
# 309       0.0          1.0     3.0          3.0                     0.0
#
#      PayRate  ...         ManagerName  ManagerID       RecruitmentSource  \
# 0      28.50  ...  Brandon R. LeBlanc        1.0      Diversity Job Fair
# 1      23.00  ...  Brandon R. LeBlanc        1.0      Website Banner Ads
# 2      29.00  ...  Brandon R. LeBlanc        1.0         Internet Search
# 3      21.50  ...  Brandon R. LeBlanc        1.0  Pay Per Click - Google
# 4      16.56  ...  Brandon R. LeBlanc        1.0      Website Banner Ads
# ..       ...  ...                 ...        ...                     ...
# 305    54.10  ...        Peter Monroe        7.0         Vendor Referral
# 306    56.20  ...        Peter Monroe        7.0       Employee Referral
# 307    53.80  ...        Peter Monroe        7.0    On-campus Recruiting
# 308    53.00  ...        Peter Monroe        7.0       Employee Referral
# 309    55.20  ...        Peter Monroe        7.0       Employee Referral
#
#     PerformanceScore  EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0        Fully Meets              2.04             2.0                  6.0
# 1        Fully Meets              5.00             4.0                  4.0
# 2        Fully Meets              3.90             5.0                  5.0
# 3        Fully Meets              3.24             3.0                  4.0
# 4        Fully Meets              5.00             3.0                  5.0
# ..               ...               ...             ...                  ...
# 305      Fully Meets              1.55             5.0                  8.0
# 306      Fully Meets              4.46             5.0                  6.0
# 307      Fully Meets              3.27             4.0                  5.0
# 308      Fully Meets              5.00             3.0                  4.0
# 309      Fully Meets              1.06             4.0                  8.0
#
#     LastPerformanceReview_Date DaysLateLast30 yearOfBirth
# 0                    1/15/2019            0.0        1987
# 1                    1/17/2019            0.0        1984
# 2                    1/18/2019            0.0        1986
# 3                          NaN            NaN        1985
# 4                    1/15/2019            0.0        1988
# ..                         ...            ...         ...
# 305                  2/12/2019            0.0        2052
# 306                   1/7/2019            0.0        1986
# 307                  1/14/2019            0.0        1983
# 308                   1/2/2019            0.0        2065
# 309                   2/5/2019            0.0        1978
#
# [310 rows x 36 columns]

# %%
current_year = 2022
def calculate_age(row):
    return (current_year - row['yearOfBirth'])

HR_data['EmployeeAge'] = HR_data.apply(lambda row: calculate_age(row), axis=1)

# %%
HR_data = HR_data[(HR_data['yearOfBirth']<2001)]
HR_data
# Out:
#               Employee_Name         EmpID  MarriedID  MaritalStatusID  \
# 0                Brown, Mia  1.103024e+09        1.0              1.0
# 1      LaRotonda, William    1.106027e+09        0.0              2.0
# 2          Steans, Tyrone    1.302053e+09        0.0              0.0
# 3           Howard, Estelle  1.211051e+09        1.0              1.0
# 4               Singh, Nan   1.307060e+09        0.0              0.0
# ..                      ...           ...        ...              ...
# 302        Carr, Claudia  N  1.010022e+09        0.0              0.0
# 304        Roehrich, Bianca  1.111030e+09        0.0              0.0
# 306          Lajiri,  Jyoti  1.108028e+09        1.0              1.0
# 307  Semizoglou, Jeremiah    9.040136e+08        1.0              1.0
# 309         Warfield, Sarah  1.301052e+09        0.0              4.0
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# 0         0.0          1.0     1.0          3.0                     1.0
# 1         1.0          1.0     1.0          3.0                     0.0
# 2         1.0          1.0     1.0          3.0                     0.0
# 3         0.0          1.0     1.0          3.0                     0.0
# 4         0.0          1.0     1.0          3.0                     0.0
# ..        ...          ...     ...          ...                     ...
# 302       0.0          2.0     3.0          3.0                     0.0
# 304       0.0          5.0     3.0          3.0                     0.0
# 306       1.0          3.0     3.0          3.0                     0.0
# 307       1.0          2.0     3.0          3.0                     0.0
# 309       0.0          1.0     3.0          3.0                     0.0
#
#      PayRate  ...  ManagerID       RecruitmentSource PerformanceScore  \
# 0      28.50  ...        1.0      Diversity Job Fair      Fully Meets
# 1      23.00  ...        1.0      Website Banner Ads      Fully Meets
# 2      29.00  ...        1.0         Internet Search      Fully Meets
# 3      21.50  ...        1.0  Pay Per Click - Google      Fully Meets
# 4      16.56  ...        1.0      Website Banner Ads      Fully Meets
# ..       ...  ...        ...                     ...              ...
# 302    61.30  ...        4.0         Vendor Referral      Fully Meets
# 304    58.50  ...        4.0         Vendor Referral      Fully Meets
# 306    56.20  ...        7.0       Employee Referral      Fully Meets
# 307    53.80  ...        7.0    On-campus Recruiting      Fully Meets
# 309    55.20  ...        7.0       Employee Referral      Fully Meets
#
#     EngagementSurvey  EmpSatisfaction SpecialProjectsCount  \
# 0               2.04              2.0                  6.0
# 1               5.00              4.0                  4.0
# 2               3.90              5.0                  5.0
# 3               3.24              3.0                  4.0
# 4               5.00              3.0                  5.0
# ..               ...              ...                  ...
# 302             5.00              5.0                  6.0
# 304             3.88              3.0                  7.0
# 306             4.46              5.0                  6.0
# 307             3.27              4.0                  5.0
# 309             1.06              4.0                  8.0
#
#     LastPerformanceReview_Date DaysLateLast30 yearOfBirth EmployeeAge
# 0                    1/15/2019            0.0        1987          35
# 1                    1/17/2019            0.0        1984          38
# 2                    1/18/2019            0.0        1986          36
# 3                          NaN            NaN        1985          37
# 4                    1/15/2019            0.0        1988          34
# ..                         ...            ...         ...         ...
# 302                  2/18/2019            0.0        1986          36
# 304                        NaN            NaN        1973          49
# 306                   1/7/2019            0.0        1986          36
# 307                  1/14/2019            0.0        1983          39
# 309                   2/5/2019            0.0        1978          44
#
# [268 rows x 37 columns]

# %%
sns.set_style('darkgrid')

# %%
sns.distplot(HR_data['EmployeeAge'])
# Out:
# /home/agnieszka/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EmployeeAge', ylabel='Density'>

# %%
HR_data['EmployeeAge'].describe()
# Out:
# count    268.000000
# mean      40.854478
# std        6.032783
# min       30.000000
# 25%       36.000000
# 50%       40.000000
# 75%       45.250000
# max       53.000000
# Name: EmployeeAge, dtype: float64

# %%
g = sns.FacetGrid(data = HR_data, col = 'Department', row = 'Sex')

# %%
g.map(plt.scatter, 'EmployeeAge', 'RaceDesc')

# %% [markdown]
# Conclusion: Employees' age varies from 30 to 53 years, the median value is 40 years old. It can be concluded that in Admin Offices both male and female employees are below mean age. Female employees in Sales are below mean age, while male employees age varies largely. In both IT and Production age distribution is very wide. Interestingly, in Software Engineering male employees' age is centered around the median.

# %% [markdown]
# Step 5: special projects vs age of employees.

# %%
sns.lmplot(x = 'EmployeeAge', y='SpecialProjectsCount', data = HR_data, hue = 'Department')

# %% [markdown]
# Conclusion: In all age groups there are employees who have done special projects. Especially in the IT/IS department special projecs are distributed in all age groups.  Only Production employees, of all ages, do not take part in the special projects.
